# %%
import pandas as pd

#Question A
mich_bids = pd.read_csv('mich_bids.csv')

mich_bids['bid_amount'] = mich_bids['Bid Per Unit'] * mich_bids['Estimated Volume']

mich_bids= mich_bids[mich_bids['Bid/Non-Bid Species'] == 'Bid']

mean = mich_bids['bid_amount'].mean()

mean
# Out:
# 18028.136367678828

# %%
import pandas as pd

#Question B
mich_bids = pd.read_csv('mich_bids.csv')

sp_mean = mich_bids.groupby('Species').mean()

sp_mean['Bid Per Unit']
# Out:
# Species
# Amer. Elm            7.266667
# Austrian Pine        8.662500
# B. Poplar           23.362281
# B. Popular          16.343263
# B. T. Aspen         51.061646
# Balsam Fir          19.441132
# Basswood            75.309488
# Beech               39.207659
# Black Ash           45.084198
# Black Cherry       188.939043
# Black Spruce        27.580093
# Black Walnut      1797.288750
# Cottonwood          22.867308
# Hemlock             17.633514
# Ironwood             5.220833
# Jack Pine           37.025486
# Misc. Sp.          122.667719
# Mix Aspen           41.671711
# Mix Hardwood        50.239059
# Mix Pine            32.936051
# Mix Softwood        22.639085
# Mixed Aspen         36.775141
# Mixed Hardwood      51.619889
# Mixed Oak           77.843587
# Mixed Pine          32.815579
# Mixed Softwood      29.178701
# N. W. Cedar         41.843671
# Norway Spruce             NaN
# Other C. Sp.        22.561846
# Paper Birch         52.750122
# Q. Aspen            30.062029
# Red Maple           71.742728
# Red Oak            187.678364
# Red Pine           111.426199
# Scotch Pine         20.613955
# Sugar Maple        469.449805
# Tamarack            18.635072
# W. Spruce           28.761392
# White Ash           66.912969
# White Oak           39.249336
# White Pine          40.489464
# Yellow Birch       229.438531
# Name: Bid Per Unit, dtype: float64

# %%
import pandas as pd

#Question C
mich_bids = pd.read_csv('mich_bids.csv')

sp_mean = mich_bids.groupby('Species').mean()

sp_mean['Estimated Volume']
# Out:
# Species
# Amer. Elm          19.500000
# Austrian Pine      35.333333
# B. Poplar          72.719774
# B. Popular         74.978267
# B. T. Aspen       218.082498
# Balsam Fir         80.367170
# Basswood           89.861681
# Beech              55.739321
# Black Ash           7.626190
# Black Cherry       19.218780
# Black Spruce      212.994274
# Black Walnut        7.480000
# Cottonwood         44.234615
# Hemlock            50.697333
# Ironwood           21.381818
# Jack Pine         360.938727
# Misc. Sp.          51.864407
# Mix Aspen         290.361999
# Mix Hardwood      318.557828
# Mix Pine           41.846021
# Mix Softwood      164.170144
# Mixed Aspen       359.888927
# Mixed Hardwood    287.605446
# Mixed Oak         201.289406
# Mixed Pine        682.380623
# Mixed Softwood    182.977541
# N. W. Cedar       137.638474
# Norway Spruce       0.400000
# Other C. Sp.      105.485496
# Paper Birch        81.916195
# Q. Aspen          347.160507
# Red Maple          95.951897
# Red Oak           124.167821
# Red Pine          312.052822
# Scotch Pine        73.045455
# Sugar Maple        64.485094
# Tamarack          116.398892
# W. Spruce          84.867776
# White Ash          29.774005
# White Oak          81.333618
# White Pine         64.158982
# Yellow Birch        4.823604
# Name: Estimated Volume, dtype: float64

# %%
import pandas as pd

#Question D
mich_bids = pd.read_csv('mich_bids.csv')

mich_bid= mich_bids[mich_bids['Bid/Non-Bid Species'] == 'Bid']

bids_mean = mich_bid.groupby('Sale #').agg({ 
    'Bid/Non-Bid Species': ['count']})

mich_non_bids= mich_bids[mich_bids['Bid/Non-Bid Species'] == 'Non-Bid']

non_bids_mean = mich_non_bids.groupby('Sale #').agg({ 
    'Bid/Non-Bid Species': ['count']})


print('bid mean :', bids_mean.mean())

print('non-bid mean :', non_bids_mean.mean())
# Out:
# bid mean : Bid/Non-Bid Species  count    12.020154
# dtype: float64
# non-bid mean : Bid/Non-Bid Species  count    16.794453
# dtype: float64

# %%
import pandas as pd

#Question D
mich_bids = pd.read_csv('mich_bids.csv')

Cords = []
for row in mich_bids['Units']:
    if row == 'Cords':
        Cords.append(1)
    else:
        Cords.append(0)
        
MBF = []
for row in mich_bids['Units']:
    if row == 'MBF':
        MBF.append(1)
    else:
        MBF.append(0)

Acres = []
for row in mich_bids['Units']:
    if row == 'Acres':
        Acres.append(1)
    else:
        Acres.append(0)
        
mich_bids['Cords'] = Cords
mich_bids['MBF'] = MBF
mich_bids['Acres'] = Acres

mich_bids

Unit_count = mich_bids.groupby('Species').agg({ 
    'Cords': ['sum'],
    'MBF': ['sum'],
    'Acres': ['sum']
})

Unit_count
# Out:
#                Cords   MBF Acres
#                  sum   sum   sum
# Species
# Amer. Elm          4     0     0
# Austrian Pine      6     0     0
# B. Poplar        175     2     0
# B. Popular       681     0     0
# B. T. Aspen     3936  2678    14
# Balsam Fir      4215    25     0
# Basswood        2096  3293     0
# Beech            740  1409     0
# Black Ash         68   184     0
# Black Cherry     912  1809     0
# Black Spruce    1835    51     0
# Black Walnut       1     9     0
# Cottonwood        13    13     0
# Hemlock           67     8     0
# Ironwood          77     0     0
# Jack Pine       7004  1615     8
# Misc. Sp.         33     2    24
# Mix Aspen       3802  1290    50
# Mix Hardwood    9117  2701    50
# Mix Pine         219    69     1
# Mix Softwood    3454    83     0
# Mixed Aspen     4033  1210    13
# Mixed Hardwood  2768   756    20
# Mixed Oak       3740  2672    35
# Mixed Pine       227    62     0
# Mixed Softwood  1113    58     0
# N. W. Cedar      569    60     0
# Norway Spruce      0     2     0
# Other C. Sp.     118    13     0
# Paper Birch     4749  2105     0
# Q. Aspen        6066   714     6
# Red Maple       6724  6614     0
# Red Oak         2067  2899     0
# Red Pine        7948  7404    28
# Scotch Pine      129    13     1
# Sugar Maple      983  5424     0
# Tamarack         696    26     0
# W. Spruce       1835   688     0
# White Ash        417  1191     0
# White Oak        953  1153     0
# White Pine      4634  3495     4
# Yellow Birch      64  1584     0
