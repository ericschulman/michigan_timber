# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
#graphing
import matplotlib.pyplot as plt
#stats
import statsmodels.api as sm
from statsmodels.base.model import GenericLikelihoodModel

#import testing
import sys
sys.path.append("../")
import selection_tests

# %%
mich_bids = pd.read_csv('panel.csv',index_col=0)
# Out:
#                                Bidder Name        Sale #  Bid Per Unit  \
# month_year
# 2004-07             Rothig Forest Products  63-001-04-01     81.358750
# 2004-07             Rothig Forest Products  63-008-04-01     39.474167
# 2004-07             Murrey Forest Products  63-001-04-01     85.875000
# 2004-07             Murrey Forest Products  63-008-04-01     46.125000
# 2004-07                              SAPPI  63-001-04-01     84.003125
# ...                                    ...           ...           ...
# 2013-05          VanDuinen Forest Products  63-015-11-01     57.398333
# 2013-05      Biewer Forest Management, LLC  63-063-11-01      0.000000
# 2013-05      Biewer Forest Management, LLC  63-066-11-01      0.000000
# 2013-05      Biewer Forest Management, LLC  63-052-11-01      0.000000
# 2013-05      Biewer Forest Management, LLC  63-015-11-01     70.141667
#
#             Highest_HIGHEST  Estimated Volume  Appraised Value Per Unit
# month_year
# 2004-07                 1.0         86.162500                 79.062500
# 2004-07                 0.0         93.366667                 39.166667
# 2004-07                 0.0         86.162500                 79.062500
# 2004-07                 0.0         93.366667                 39.166667
# 2004-07                 0.0         86.162500                 79.062500
# ...                     ...               ...                       ...
# 2013-05                 0.0        555.850000                 46.441667
# 2013-05                 0.0        195.050000                 59.666667
# 2013-05                 0.0         38.628571                 24.150000
# 2013-05                 0.0         64.728571                 49.400000
# 2013-05                 1.0        555.850000                 46.441667
#
# [1683 rows x 6 columns]

# %%
# Modify the dataset by filling NaNs and dropping NO BIDS
mich_bids['Bid Per Unit'] = mich_bids['Bid Per Unit'].fillna(0)
mich_bids = mich_bids[mich_bids['Bidder Name'] != ' NO BIDS']

# %%
# Fit the model
x = mich_bids[['Highest_HIGHEST', 'Estimated Volume', 'Appraised Value Per Unit']].copy()
y = mich_bids['Bid Per Unit']
tobit_model = selection_tests.Tobit(y,x).fit()
tobit_model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 2.434897
#          Iterations: 353
#          Function evaluations: 618
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 Tobit Results
# ==============================================================================
# Dep. Variable:           Bid Per Unit   Log-Likelihood:                -4097.9
# Model:                          Tobit   AIC:                             8202.
# Method:            Maximum Likelihood   BIC:                             8218.
# Date:                Fri, 02 Apr 2021
# Time:                        09:42:41
# No. Observations:                1683
# Df Residuals:                    1680
# Df Model:                           2
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Highest_HIGHEST             91.9492      6.960     13.210      0.000      78.307     105.591
# Estimated Volume            -0.1025      0.012     -8.370      0.000      -0.126      -0.078
# Appraised Value Per Unit    -0.0254      0.054     -0.473      0.636      -0.131       0.080
# var                       5956.0473    396.043     15.039      0.000    5179.816    6732.278
# ============================================================================================
# """
